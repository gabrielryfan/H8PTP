# %% [markdown]
# # Car sales

# %% [markdown]
# berikut merupakan data set penjualan mobil. Dari data ini penulis diminta untuk mencari faktor apa yang sangat mempengaruhi penjualan dari suatu model mobil. Selanjutnnya penulis diminta untuk memprediksi penjualan mobil kedepannya.

# %% [markdown]
# # Informasi Data

# %% [markdown]
# data ini diambil dari sumber sebagai berikut.
# https://www.kaggle.com/gagandeep16/car-sales

# %% [markdown]
# # Tujuan

# %% [markdown]
# Tujuan Penulis membuat studi kasus ini adalah :
#     1. menentukan Korelasi antara atribut yang ada.
#     2. Memprediksi penjualan mobil per model untuk kedepannya

# %%
from scipy import stats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Car_sales.csv")

# %%
### prediksi harga linear regression

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.corr()
# Out:
#                      Sales_in_thousands  __year_resale_value  \
# Sales_in_thousands             1.000000            -0.279034
# __year_resale_value           -0.279034             1.000000
# Price_in_thousands            -0.304734             0.953840
# Engine_size                    0.019983             0.531330
# Horsepower                    -0.197756             0.769081
# Wheelbase                      0.358179            -0.052270
# Width                          0.140918             0.178767
# Length                         0.254980             0.026548
# Curb_weight                    0.008628             0.361557
# Fuel_capacity                  0.086540             0.325567
# Fuel_efficiency               -0.016764            -0.399880
# Power_perf_factor             -0.223252             0.827123
#
#                      Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# Sales_in_thousands            -0.304734     0.019983   -0.197756   0.358179
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
# Manufacturer           157 non-null object
# Model                  157 non-null object
# Sales_in_thousands     157 non-null float64
# __year_resale_value    121 non-null float64
# Vehicle_type           157 non-null object
# Price_in_thousands     155 non-null float64
# Engine_size            156 non-null float64
# Horsepower             156 non-null float64
# Wheelbase              156 non-null float64
# Width                  156 non-null float64
# Length                 156 non-null float64
# Curb_weight            155 non-null float64
# Fuel_capacity          156 non-null float64
# Fuel_efficiency        154 non-null float64
# Latest_Launch          157 non-null object
# Power_perf_factor      155 non-null float64
# dtypes: float64(12), object(4)
# memory usage: 19.8+ KB

# %%
df.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %% [markdown]
# ### Mobil Dengan Model Paling Variatif

# %%
df["Manufacturer"].value_counts()
# Out:
# Ford          11
# Dodge         11
# Chevrolet      9
# Toyota         9
# Mercedes-B     9
# Nissan         7
# Chrysler       7
# Mitsubishi     7
# Volkswagen     6
# Mercury        6
# Pontiac        6
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Saturn         5
# Honda          5
# Cadillac       5
# Acura          4
# Buick          4
# Plymouth       4
# BMW            3
# Lincoln        3
# Porsche        3
# Hyundai        3
# Audi           3
# Jeep           3
# Subaru         2
# Saab           2
# Jaguar         1
# Infiniti       1
# Name: Manufacturer, dtype: int64

# %% [markdown]
# ### Sales Terbesar Ford

# %%
df.loc[df["Manufacturer"] == "Ford", "Sales_in_thousands"].max()
# Out:
# 540.561

# %%
df.loc[df["Manufacturer"] == "Ford", "Sales_in_thousands"].min()
# Out:
# 35.068000000000005

# %% [markdown]
# ### Model Ford

# %%
df.loc[df["Manufacturer"] == "Ford", "Model"].value_counts()
# Out:
# Focus             1
# Contour           1
# F-Series          1
# Ranger            1
# Expedition        1
# Taurus            1
# Crown Victoria    1
# Mustang           1
# Escort            1
# Windstar          1
# Explorer          1
# Name: Model, dtype: int64

# %%
ford = df[df.Manufacturer == "Ford"]
ford
# Out:
#    Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 46         Ford          Escort              70.227                7.425
# 47         Ford         Mustang             113.369               12.760
# 48         Ford         Contour              35.068                8.835
# 49         Ford          Taurus             245.815               10.055
# 50         Ford           Focus             175.670                  NaN
# 51         Ford  Crown Victoria              63.403               14.210
# 52         Ford        Explorer             276.747               16.640
# 53         Ford        Windstar             155.787               13.175
# 54         Ford      Expedition             125.338               23.575
# 55         Ford          Ranger             220.650                7.850
# 56         Ford        F-Series             540.561               15.075
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# ### Total Sales Ford Dalam Ribuan

# %%
df.loc[df["Manufacturer"] == "Ford", "Sales_in_thousands"].sum()
# Out:
# 2022.6350000000002

# %%
2022.6350000000002 * 1000
# Out:
# 2022635.0000000002

# %% [markdown]
# #2.002.635

# %%
total = df.groupby("Manufacturer", sort=False)["Sales_in_thousands"].sum()
total
# Out:
# Manufacturer
# Acura           79.005
# Audi            40.557
# BMW             46.505
# Buick          242.019
# Cadillac       112.178
# Chevrolet      554.365
# Chrysler       201.721
# Dodge          910.149
# Ford          2022.635
# Honda          592.674
# Hyundai        137.326
# Infiniti        23.713
# Jaguar          15.467
# Jeep           293.153
# Lexus          106.843
# Lincoln         85.634
# Mitsubishi     180.895
# Mercury        237.999
# Mercedes-B     117.125
# Nissan         399.635
# Oldsmobile     178.989
# Plymouth        64.001
# Pontiac        370.534
# Porsche         12.128
# Saab            21.306
# Saturn         168.850
# Subaru          80.135
# Toyota         740.205
# Volkswagen     209.212
# Volvo           75.740
# Name: Sales_in_thousands, dtype: float64

# %% [markdown]
# ### Ranking Total Sales Per Merk

# %%
total.sort_values(ascending=False)
# Out:
# Manufacturer
# Ford          2022.635
# Dodge          910.149
# Toyota         740.205
# Honda          592.674
# Chevrolet      554.365
# Nissan         399.635
# Pontiac        370.534
# Jeep           293.153
# Buick          242.019
# Mercury        237.999
# Volkswagen     209.212
# Chrysler       201.721
# Mitsubishi     180.895
# Oldsmobile     178.989
# Saturn         168.850
# Hyundai        137.326
# Mercedes-B     117.125
# Cadillac       112.178
# Lexus          106.843
# Lincoln         85.634
# Subaru          80.135
# Acura           79.005
# Volvo           75.740
# Plymouth        64.001
# BMW             46.505
# Audi            40.557
# Infiniti        23.713
# Saab            21.306
# Jaguar          15.467
# Porsche         12.128
# Name: Sales_in_thousands, dtype: float64

# %%
salesmodel = df.groupby(["Manufacturer", "Model"])["Sales_in_thousands"].count()

# %%
salesmodel.tail
# Out:
# <bound method NDFrame.tail of Manufacturer  Model
# Acura         CL         1
#               Integra    1
#               RL         1
#               TL         1
# Audi          A4         1
#                         ..
# Volvo         S40        1
#               S70        1
#               S80        1
#               V40        1
#               V70        1
# Name: Sales_in_thousands, Length: 157, dtype: int64>

# %%
df["Vehicle_type"].value_counts()
# Out:
# Passenger    116
# Car           41
# Name: Vehicle_type, dtype: int64

# %%
sales = df.copy()

# %%
sales.shape
# Out:
# (157, 16)

# %% [markdown]
# ### Mencari Jumlah Pendapatan

# %% [markdown]
# Mengalikan penjualan dengan harga satuan

# %%
sales["total_income"] = df.Sales_in_thousands * df.Price_in_thousands

# %%
sales.shape
# Out:
# (157, 17)

# %%
sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
totalincome = sales.groupby("Manufacturer", sort=False)["total_income"].sum()
totalincome.sort_values(ascending=False)
# Out:
# Manufacturer
# Ford          45776.128865
# Dodge         18000.608380
# Toyota        13288.560856
# Honda          9940.305575
# Chevrolet      9610.653260
# Nissan         8833.903124
# Pontiac        8074.596455
# Jeep           6768.565740
# Buick          6219.486635
# Mercedes-B     5364.257400
# Mercury        5019.988470
# Cadillac       4541.067295
# Oldsmobile     4199.645911
# Lexus          4058.708215
# Volkswagen     3702.618010
# Lincoln        3636.519970
# Mitsubishi     3535.058045
# Chrysler       3461.312965
# Volvo          2249.237600
# Saturn         2153.650490
# Acura          1842.960100
# Subaru         1732.791025
# Hyundai        1628.063074
# BMW            1523.087230
# Audi           1212.465030
# Plymouth       1033.834710
# Infiniti        698.703545
# Jaguar          661.987600
# Saab            620.607420
# Porsche         602.923880
# Name: total_income, dtype: float64

# %% [markdown]
# ### Kisaran Harga Penjualan Mobil Paling Populer

# %%
sales[sales["Manufacturer"] == "Ford"].groupby("Price_in_thousands")["Sales_in_thousands"].sum().plot()

# %%
sales[sales["Manufacturer"] == "Ford"].groupby("Horsepower")["Sales_in_thousands"].sum().plot()

# %%
sales[sales["Manufacturer"] == "Ford"].groupby("Horsepower")["Sales_in_thousands"].sum().plot()

# %%
sales.groupby("Power_perf_factor")["Sales_in_thousands"].sum().plot()

# %%
sales.groupby("Engine_size")["Sales_in_thousands"].sum().plot()

# %% [markdown]
# ### Penjualan Paling Laris

# %% [markdown]
# dapat disimpulkan berikut merupakan merk mobil terlaris

# %%
total.sort_values(ascending=False).head(10).plot(kind="bar");plt.title("Total Penjualan");

# %% [markdown]
# Dan berikut merupakan penjualan paling kecil

# %%
total.sort_values(ascending=True).head(10).plot(kind="bar")

# %%
total.sort_values(ascending=False).head(10).plot(kind="pie");plt.title("Persentase Penjualan");

# %% [markdown]
# ### Pendapatan Paling Besar

# %% [markdown]
# berikut merupakan total pendapatan paling besar dengan cara mengalikan total penjuaan dengan harga satuan mobil

# %%
totalincome.sort_values(ascending=False).head(10).plot(kind="bar") ;plt.title("Pendapatan Terbesar");

# %% [markdown]
# ### Pendapatan Paling Kecil

# %%
totalincome.sort_values(ascending=True).head(10).plot(kind="bar")

# %%
total.sort_values(ascending=False).head(10).plot(kind="pie")

# %%
sales.groupby("Fuel_capacity")["Sales_in_thousands"].sum().plot()

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
total = df.groupby("Sales_in_thousands", sort=False)["Power_perf_factor"].sum()
total.sort_values(ascending=False).head().plot(kind="bar")

# %%
chart=sns.catplot(x="Manufacturer", y="__year_resale_value",hue="Vehicle_type", s=15, data=df)
chart.set_xticklabels(rotation=90)

# %%
sns.catplot(x = "Manufacturer", y = "__year_resale_value", kind = "box", data = df)

# %%
resale=sales["__year_resale_value"]
resale.head()
# Out:
# 0    16.360
# 1    19.875
# 2    18.225
# 3    29.725
# 4    22.255
# Name: __year_resale_value, dtype: float64

# %% [markdown]
# ### Nilai Statistik Shapiro

# %%
stat, p = stats.shapiro(resale)
stat, p
# Out:
# (nan, 1.0)

# %%
stat, p = stats.jarque_bera(resale)
stat, p
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1807: RuntimeWarning: invalid value encountered in greater_equal
#   cond2 = (x >= _b) & cond0
# (nan, nan)

# %%
resale2=sales["Fuel_efficiency"]
resale2.head()
# Out:
# 0    28.0
# 1    25.0
# 2    26.0
# 3    22.0
# 4    27.0
# Name: Fuel_efficiency, dtype: float64

# %%
stat, p = stats.pearsonr(resale, resale2)
stat, p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-968e3c7c7298> in <module>
# ----> 1 stat, p = stats.pearsonr(resale, resale2)
#       2 stat, p
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3419     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3420     # [-5e210, 5e210, 3e200, -3e200]
# -> 3421     normxm = linalg.norm(xm)
#    3422     normym = linalg.norm(ym)
#    3423
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims)
#     135     """
#     136     # Differs from numpy only in non-finite handling and the use of blas.
# --> 137     a = np.asarray_chkfinite(a)
#     138
#     139     # Only use optimized norms if axis and keepdims are not specified.
#
# ...

# %%
stat, p = stats.spearmanr(resale, resale2)
stat, p
# Out:
# (nan, nan)

# %%
import scipy.stats

scipy.stats.spearmanr(resale, resale2)
# Out:
# SpearmanrResult(correlation=nan, pvalue=nan)

# %%
scipy.stats.pearsonr(resale, resale2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-6adb146b52a4> in <module>
# ----> 1 scipy.stats.pearsonr(resale, resale2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3419     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3420     # [-5e210, 5e210, 3e200, -3e200]
# -> 3421     normxm = linalg.norm(xm)
#    3422     normym = linalg.norm(ym)
#    3423
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims)
#     135     """
#     136     # Differs from numpy only in non-finite handling and the use of blas.
# --> 137     a = np.asarray_chkfinite(a)
#     138
#     139     # Only use optimized norms if axis and keepdims are not specified.
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
# ...

# %%
scipy.stats.kendalltau(resale, resale2)
# Out:
# KendalltauResult(correlation=nan, pvalue=nan)

# %%
print(scipy.stats.pearsonr(resale, resale2)[0])    # Pearson's r
print(scipy.stats.spearmanr(resale, resale2)[0])   # Spearman's rho
print(scipy.stats.kendalltau(resale, resale2)[0])  # Kendall's tau
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-aaa4e25c3381> in <module>
# ----> 1 print(scipy.stats.pearsonr(resale, resale2)[0])    # Pearson's r
#       2 print(scipy.stats.spearmanr(resale, resale2)[0])   # Spearman's rho
#       3 print(scipy.stats.kendalltau(resale, resale2)[0])  # Kendall's tau
#       4
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3419     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3420     # [-5e210, 5e210, 3e200, -3e200]
# -> 3421     normxm = linalg.norm(xm)
#    3422     normym = linalg.norm(ym)
#    3423
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims)
#     135     """
#     136     # Differs from numpy only in non-finite handling and the use of blas.
# --> 137     a = np.asarray_chkfinite(a)
#     138
# ...

# %%
scipy.stats.spearmanr(resale, resale2).correlation
# Out:
# nan

# %%
scipy.stats.kendalltau(resale, resale2).correlation
# Out:
# nan

# %%
r, p = scipy.stats.pearsonr(resale, resale2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-e26b074c4226> in <module>
# ----> 1 r, p = scipy.stats.pearsonr(resale, resale2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3419     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3420     # [-5e210, 5e210, 3e200, -3e200]
# -> 3421     normxm = linalg.norm(xm)
#    3422     normym = linalg.norm(ym)
#    3423
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims)
#     135     """
#     136     # Differs from numpy only in non-finite handling and the use of blas.
# --> 137     a = np.asarray_chkfinite(a)
#     138
#     139     # Only use optimized norms if axis and keepdims are not specified.
#
# ...

# %%
resale.corr(resale2)

# %%
resale2.corr(resale)

# %%
resale.corr(resale2, method='spearman')
# Out:
# -0.5688472739521485

# %%
resale.corr(resale2, method='kendall')
# Out:
# -0.39973939560958943

# %%
result = scipy.stats.linregress(resale, resale2)

# %%
result
# Out:
# LinregressResult(slope=nan, intercept=nan, rvalue=nan, pvalue=nan, stderr=nan)

# %%
df.corr()
# Out:
#                      Sales_in_thousands  __year_resale_value  \
# Sales_in_thousands             1.000000            -0.279034
# __year_resale_value           -0.279034             1.000000
# Price_in_thousands            -0.304734             0.953840
# Engine_size                    0.019983             0.531330
# Horsepower                    -0.197756             0.769081
# Wheelbase                      0.358179            -0.052270
# Width                          0.140918             0.178767
# Length                         0.254980             0.026548
# Curb_weight                    0.008628             0.361557
# Fuel_capacity                  0.086540             0.325567
# Fuel_efficiency               -0.016764            -0.399880
# Power_perf_factor             -0.223252             0.827123
#
#                      Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# Sales_in_thousands            -0.304734     0.019983   -0.197756   0.358179
# ...

# %%
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
# Manufacturer           157 non-null object
# Model                  157 non-null object
# Sales_in_thousands     157 non-null float64
# __year_resale_value    121 non-null float64
# Vehicle_type           157 non-null object
# Price_in_thousands     155 non-null float64
# Engine_size            156 non-null float64
# Horsepower             156 non-null float64
# Wheelbase              156 non-null float64
# Width                  156 non-null float64
# Length                 156 non-null float64
# Curb_weight            155 non-null float64
# Fuel_capacity          156 non-null float64
# Fuel_efficiency        154 non-null float64
# Latest_Launch          157 non-null object
# Power_perf_factor      155 non-null float64
# dtypes: float64(12), object(4)
# memory usage: 19.8+ KB

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
### apus year resale value

# %%
data = df.drop("__year_resale_value", axis=1)

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 2          Acura       CL              14.114    Passenger
# 3          Acura       RL               8.588    Passenger
# 4           Audi       A4              20.397    Passenger
# ..           ...      ...                 ...          ...
# 152        Volvo      V40               3.545    Passenger
# 153        Volvo      S70              15.245    Passenger
# 154        Volvo      V70              17.531    Passenger
# 155        Volvo      C70               3.493    Passenger
# 156        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %% [markdown]
# # HASIL AKHIR

# %%
baru1 = df.fillna(0)

# %%
baru2 = baru1.drop("__year_resale_value", axis=1)

# %%
baru3 = df[['Model','Sales_in_thousands']] #ini kenapa gabisa ya
baru3
# Out:
#        Model  Sales_in_thousands
# 0    Integra              16.919
# 1         TL              39.384
# 2         CL              14.114
# 3         RL               8.588
# 4         A4              20.397
# ..       ...                 ...
# 152      V40               3.545
# 153      S70              15.245
# 154      V70              17.531
# 155      C70               3.493
# 156      S80              18.969
#
# [157 rows x 2 columns]

# %%
baru2
# Out:
#     Manufacturer    Model  Sales_in_thousands Vehicle_type  \
# 0          Acura  Integra              16.919    Passenger
# 1          Acura       TL              39.384    Passenger
# 2          Acura       CL              14.114    Passenger
# 3          Acura       RL               8.588    Passenger
# 4           Audi       A4              20.397    Passenger
# ..           ...      ...                 ...          ...
# 152        Volvo      V40               3.545    Passenger
# 153        Volvo      S70              15.245    Passenger
# 154        Volvo      V70              17.531    Passenger
# 155        Volvo      C70               3.493    Passenger
# 156        Volvo      S80              18.969    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
baru2.head(50)
# Out:
#    Manufacturer           Model  Sales_in_thousands Vehicle_type  \
# 0         Acura         Integra              16.919    Passenger
# 1         Acura              TL              39.384    Passenger
# 2         Acura              CL              14.114    Passenger
# 3         Acura              RL               8.588    Passenger
# 4          Audi              A4              20.397    Passenger
# 5          Audi              A6              18.780    Passenger
# 6          Audi              A8               1.380    Passenger
# 7           BMW            323i              19.747    Passenger
# 8           BMW            328i               9.231    Passenger
# 9           BMW            528i              17.527    Passenger
# 10        Buick         Century              91.561    Passenger
# 11        Buick           Regal              39.350    Passenger
# 12        Buick     Park Avenue              27.851    Passenger
# ...

# %%
baru2.isnull().sum()
# Out:
# Manufacturer          0
# Model                 0
# Sales_in_thousands    0
# Vehicle_type          0
# Price_in_thousands    0
# Engine_size           0
# Horsepower            0
# Wheelbase             0
# Width                 0
# Length                0
# Curb_weight           0
# Fuel_capacity         0
# Fuel_efficiency       0
# Latest_Launch         0
# Power_perf_factor     0
# dtype: int64

# %% [markdown]
# # korelasi Spearman

# %%
price=baru2["Price_in_thousands"]
price.head()
# Out:
# 0    21.50
# 1    28.40
# 2     0.00
# 3    42.00
# 4    23.99
# Name: Price_in_thousands, dtype: float64

# %%
efisien=baru2["Fuel_efficiency"]
price.head()
# Out:
# 0    21.50
# 1    28.40
# 2     0.00
# 3    42.00
# 4    23.99
# Name: Price_in_thousands, dtype: float64

# %%
engine=baru2["Engine_size"]
engine.head()
# Out:
# 0    1.8
# 1    3.2
# 2    3.2
# 3    3.5
# 4    1.8
# Name: Engine_size, dtype: float64

# %%
stat, p = stats.shapiro(price)
stat, p
# Out:
# (0.8606125116348267, 6.79795941760375e-11)

# %%
stat, p = stats.jarque_bera(price)
stat, p
# Out:
# (140.80484753973403, 0.0)

# %%
stat, p = stats.pearsonr(price, engine)
stat, p
# Out:
# (0.6289393612683705, 1.1427333252480828e-18)

# %%
stat, p = stats.spearmanr(price, engine)
stat, p
# Out:
# (0.6621861681638096, 3.604080559634642e-21)

# %%
import scipy.stats

scipy.stats.spearmanr(price, engine)
# Out:
# SpearmanrResult(correlation=0.6621861681638096, pvalue=3.604080559634642e-21)

# %%
scipy.stats.pearsonr(price, engine)
# Out:
# (0.6289393612683705, 1.1427333252480828e-18)

# %%
print(scipy.stats.spearmanr(price, engine)[0])   # Spearman's rho
# Out:
# 0.6621861681638096

# %% [markdown]
# ## Berarti dapat disimpulkan hubungan harga mobil dan Ukuran mesin pada mobil sangat kuat.

# %% [markdown]
# semakin besar ukuran mesin maka akan semakin mahal harganya

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
penjualan=baru2["Sales_in_thousands"]
penjualan.head()
# Out:
# 0    16.919
# 1    39.384
# 2    14.114
# 3     8.588
# 4    20.397
# Name: Sales_in_thousands, dtype: float64

# %%
penjualan=baru2["Fuel_efficiency"]
penjualan.head()
# Out:
# 0    28.0
# 1    25.0
# 2    26.0
# 3    22.0
# 4    27.0
# Name: Fuel_efficiency, dtype: float64

# %%
import seaborn as sea

# %%
sea.lmplot(x="Sales_in_thousands", y="Fuel_efficiency",data=baru2,markers=".",
           order=2, ci=None, scatter_kws={"color": "red"},
         line_kws={"linewidth":5,"color":"lightblue"},aspect=1);
plt.title("tes");

# %% [markdown]
# # Efisiensi Bensin dan  Ukuran Mesin (cc mesin)

# %%
print(scipy.stats.spearmanr(engine, efisien)[0])   # Spearman's rho
# Out:
# -0.738671105108869

# %% [markdown]
# Efisiensi bahan bakar berbanding terbalik dengan ukuran mesin

# %% [markdown]
# Semakin kecil ukuran mesinnya, semakin efisien juga penggunaan bahan bakarnya.
# begitu juga sebaliknya, semakin besar ukuran mesin makan penggunaan bahan bakar semakin boros.

# %%
sea.lmplot(x="Fuel_efficiency", y="Engine_size",data=baru2,markers=".",
           order=2, ci=None, scatter_kws={"color": "red"},
         line_kws={"linewidth":5,"color":"lightblue"},aspect=1);
plt.title("tes");

# %% [markdown]
# # Power Performance Factor dan Ukuran Mesin

# %%
PPF=baru2["Power_perf_factor"]
PPF.head()
# Out:
# 0    58.280150
# 1    91.370778
# 2     0.000000
# 3    91.389779
# 4    62.777639
# Name: Power_perf_factor, dtype: float64

# %%
print(scipy.stats.spearmanr(PPF, engine)[0])   # Spearman's rho
# Out:
# 0.8061159774266556

# %%
hubungan keduanya sangat kuat

# %% [markdown]
# Dapat disimpulkan bahwa Power Performance Factor berbanding lurus dengan ukuran mesin.
# semakin besar ukuran mesin maka akan semakin kuat Power yang dihasilkan.

# %% [markdown]
# # Power Performance Factor dan Fuel Efficiency

# %%
print(scipy.stats.spearmanr(PPF, efisien)[0])   # Spearman's rho
# Out:
# -0.6285012944892651

# %% [markdown]
# Power Performance Factor berbanding terbalik dengan efisiensi bahan bakar

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
tangki=baru2["Fuel_capacity"]

# %%
Wheel=baru2["Wheelbase"]
panjang=baru2["Length"]
HP = baru2["Horsepower"] 
Clearance = baru2["Curb_weight"]

# %%
sales=baru2["Sales_in_thousands"]
sales.head()
# Out:
# 0    16.919
# 1    39.384
# 2    14.114
# 3     8.588
# 4    20.397
# Name: Sales_in_thousands, dtype: float64

# %% [markdown]
# # Faktor Larisnya Penjualan

# %%
print(scipy.stats.spearmanr(sales, price)[0])   # Spearman's rho
print(scipy.stats.spearmanr(sales, engine)[0])   # Spearman's rho
print(scipy.stats.spearmanr(sales, efisien)[0])   # Spearman's rho
print(scipy.stats.spearmanr(sales, PPF)[0])   # Spearman's rho
print(scipy.stats.spearmanr(sales, tangki)[0])   # Spearman's rho
print(scipy.stats.spearmanr(sales, panjang)[0])   # Spearman's rho 
print(scipy.stats.spearmanr(sales, HP)[0])   # Spearman's rho
print(scipy.stats.spearmanr(sales, Clearance)[0])
# Out:
# -0.4782961265477587
# -0.0873602589629095
# 0.10279248301686482
# -0.34616833732627605
# -0.050241111457910805
# 0.1306023088290328
# -0.32312935068643595
# -0.06190407156223493

# %% [markdown]
# Dapat disimpulkan bahwa hal yang paling mempengaruhi penjualan adalah, Harga, Performa Mesin, dan HorsePower
#
# 1. Semakin Murah harganya,makan akan semakin laris
# 2. Semakin Kuat Performa Mesinnya, semakin laris penjualannya
# 3. Semakin besar Horsepower yang dihasilkan, makan akan semakin laris penjualannya.

# %% [markdown]
# # Prediksi Penjualan

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs

# %%
sales=baru2["Sales_in_thousands"]
sales.head()
# Out:
# 0    16.919
# 1    39.384
# 2    14.114
# 3     8.588
# 4    20.397
# Name: Sales_in_thousands, dtype: float64

# %%
prediksi = baru2["Sales_in_thousands","Price_in_thousands"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Sales_in_thousands', 'Price_in_thousands')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-9e2c3ccc45df> in <module>
# ...

# %%
baru3 = baru2

# %%
baru3.reshape(1,-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-70f6f0756187> in <module>
# ----> 1 baru3.reshape(1,-1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
model = LogisticRegression()

# %%
model.fit(price, sales)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-c057005c2b9a> in <module>
# ----> 1 model.fit(price, sales)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# ...

# %%
# example of training a final classification model
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# fit final model
model = LogisticRegression()
model.fit(baru3,price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-197-b4557208bcda> in <module>
#       4 # fit final model
#       5 model = LogisticRegression()
# ----> 6 model.fit(baru3,price)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# ...

# %%
sales.reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-169-6b0733a0bd56> in <module>
# ----> 1 sales.reshape(-1,1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %% [markdown]
# # KESIMPULAN

# %% [markdown]
# 1. Hubungan harga mobil dan Ukuran mesin pada mobil sangat kuat. semakin besar ukuran mesin maka akan semakin mahal harganya
# 2. Power Performance Factor berbanding terbalik dengan efisiensi bahan bakar
# 3. Dapat disimpulkan bahwa Power Performance Factor berbanding lurus dengan ukuran mesin.
# semakin besar ukuran mesin maka akan semakin kuat Power yang dihasilkan.
# 4. Efisiensi bahan bakar berbanding terbalik dengan ukuran mesin
# Semakin kecil ukuran mesinnya, semakin efisien juga penggunaan bahan bakarnya. begitu juga sebaliknya, semakin besar ukuran mesin makan penggunaan bahan bakar semakin boros.
# 5. hubungan harga mobil dan Ukuran mesin pada mobil sangat kuat. Semakin besar ukuran mesin (cc) maka akan semakin mahal harganya.
# 6. Yang paling mempengaruhi Penjualan adalah Harga, Performa Mesin, dan yang terakhir Horsepower.
